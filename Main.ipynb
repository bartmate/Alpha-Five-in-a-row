# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17796926906626705561
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 1436759479276711437
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 16954669942172893653
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3181314048
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 16268656240482841132
# physical_device_desc: "device: 0, name: GeForce GTX 1050 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1"
# ]

# %%
from Pipeline import Pipeline
# Out:
# Using TensorFlow backend.

# %%
pl = Pipeline(verbose = 4)
pl.main_loop()
# Out:
# Loop -  0
# Self play
# 0 start_index =  0
# 1 - move:  2 0 ; next_index:  1
#  ABCDE
# -----------------
# |  X  |1
# |     |2
# |     |3
# |     |4
# |     |5
# -----------------
# 2 - move:  1 0 ; next_index:  2
#  ABCDE
# -----------------
# | OX  |1
# |     |2
# |     |3
# |     |4
# |     |5
# -----------------
# 3 - move:  0 0 ; next_index:  3
#  ABCDE
# -----------------
# |XOX  |1
# |     |2
# |     |3
# |     |4
# |     |5
# -----------------
# 4 - move:  4 1 ; next_index:  4
#  ABCDE
# -----------------
# |XOX  |1
# |    O|2
# |     |3
# |     |4
# |     |5
# -----------------
# 5 - move:  2 4 ; next_index:  5
#  ABCDE
# -----------------
# |XOX  |1
# |    O|2
# |     |3
# |     |4
# |  X  |5
# -----------------
# 6 - move:  3 1 ; next_index:  6
#  ABCDE
# -----------------
# |XOX  |1
# |   OO|2
# |     |3
# |     |4
# |  X  |5
# -----------------
# 7 - move:  0 2 ; next_index:  7
#  ABCDE
# -----------------
# |XOX  |1
# |   OO|2
# |X    |3
# |     |4
# |  X  |5
# ...
