# %%
import numpy as np

# %%
from Game import *

# %%
#Test Game I
g = Game()
while (g.winner==0):
    x = np.random.randint(15)
    y = np.random.randint(15)
    if g.grid[x,y]==0:
        g.move(x,y)
        g.print()
print(g.winner,g.moves[g.nr-1,:])
# Out:
# -----------------
# |               |
# |               |
# |               |
# |               |
# |               |
# |        X      |
# |               |
# |               |
# |               |
# |               |
# |               |
# |               |
# |               |
# |               |
# |               |
# -----------------
# -----------------
# |               |
# |               |
# |               |
# |               |
# |               |
# |        X      |
# |               |
# |               |
# |               |
# |               |
# |               |
# |            O  |
# |               |
# |               |
# |               |
# -----------------
# -----------------
# |               |
# |               |
# |               |
# |               |
# |               |
# |        X      |
# |               |
# |               |
# |               |
# |         X     |
# |               |
# |            O  |
# |               |
# |               |
# |               |
# ...

# %%
#Test Game II
g = Game()
for x in range(15):
    for y in range(3):
        g.move(x,y)

for x in range(15):
    for y in range(4,7):
        g.move(x,y)

for x in range(15):
    for y in range(8,11):
        g.move(x,y)

for x in range(15):
    for y in range(12,15):
        g.move(x,y)

for x in range(15):
    g.move(x,3)
for x in range(15):
    g.move(x,7)
for x in range(15):
    g.move(x,11)
        
        
g.print()
print(g.nr,g.winner)
# Out:
# -----------------
# |XOXOXOXOXOXOXOX|
# |OXOXOXOXOXOXOXO|
# |XOXOXOXOXOXOXOX|
# |XOXOXOXOXOXOXOX|
# |OXOXOXOXOXOXOXO|
# |XOXOXOXOXOXOXOX|
# |OXOXOXOXOXOXOXO|
# |OXOXOXOXOXOXOXO|
# |XOXOXOXOXOXOXOX|
# |OXOXOXOXOXOXOXO|
# |XOXOXOXOXOXOXOX|
# |XOXOXOXOXOXOXOX|
# |OXOXOXOXOXOXOXO|
# |XOXOXOXOXOXOXOX|
# |OXOXOXOXOXOXOXO|
# -----------------
# 225 3

# %%
print(DRAW)
# Out:
# 3
